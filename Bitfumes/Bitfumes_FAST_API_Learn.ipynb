# %% [markdown]
# # 비밀번호 hashing Password

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Relationships table connect table

# %% [markdown]
# # API Router
#
# - 워킹 디렉토리 기준으로 잡아야 함
# - fastapi 워킹 디렉토리 기준은 main.py 이기 때문에
# - framework사용시 working dir 기준으로 path를 잡아야 해결됨

# %% [markdown]
# # API Router operators
# - django와 유사

# %% [markdown]
# # Blog and User Respositories

# %% [markdown]
#  - routers에 있는 코드를 단위로 찢어서 관리

# %% [markdown]
# # Login and Verify Password
# ![image.png](attachment:image.png)

# %% [markdown]
# # JWT Access Token

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# token.py
# # https://fastapi.tiangolo.com/tutorial/security/oauth2-jwt/?h=jwt

# %% [markdown]
# # Routes behind Authentication

# %% [markdown]
# oauth2.py

# %% [markdown]
# 3:45:52

# %% [markdown]
# # Deploy using Deta.sh
